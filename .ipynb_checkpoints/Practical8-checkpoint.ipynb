# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
sns.histplot(data=df, x = 'fare',kde=True)
plt.title("Histogram of fare")
plt.xlabel('fare')
plt.ylabel('count')
plt.show()

# %%
sns.scatterplot(data=df, x='age', y='fare')
plt.title('Age vs. Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
sns.boxplot(data=df, x='class', y='fare')
plt.title('Fare Distribution by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Fare')
plt.show()

# %%
sns.countplot(data=df, x='survived')
plt.title('Count of Passengers - Survivors')
plt.xlabel('Survived')
plt.ylabel('Count')
plt.show()
